# %% [markdown]
# ## Welcome to Deep Learning!
# Using Keras and Tensorflow you'll learn how to:
#
#
# *   create a fully-connected neural network architecture
# *   apply neural nets to two classic ML problems: regression and classification
# * train neural nets with stochastic gradient descent, and
# improve performance with dropout, batch normalization, and other techniques

# %% [markdown]
# ## 1. A Single Neuron

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Example - The Linear Unit as a Model

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Multiple Inputs

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Linear Units in Keras

# %%
from tensorflow import keras
from keras import layers

# Create a network with 1 linear unit
model = keras.Sequential([
    layers.Dense(units=1, input_shape=[3])
])

# %% [markdown]
# # Define a linear model for the Red Wine Quality dataset.
#
# The *Red Wine Quality* dataset consists of physiochemical measurements from about 1600 Portuguese red wines.  Also included is a quality rating for each wine from blind taste-tests.

# %%
import pandas as pd

red_wine = pd.read_csv("./file_csv/red-wine.csv")
red_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
red_wine.shape # (rows, columns)
# Out:
# (1599, 12)

# %%
input_shape = [len(red_wine.columns)-1]

# %%
from tensorflow import keras
from keras import layers

model = keras.Sequential([
    layers.Dense(units=1,input_shape=input_shape)
])

# %%
w, b = model.weights
print("Weights\n{}\n\nBias\n{}".format(w, b))
# Out:
# Weights
# <tf.Variable 'dense_29/kernel:0' shape=(11, 1) dtype=float32, numpy=
# array([[-0.05522162],
#        [ 0.37201172],
#        [ 0.5857839 ],
#        [-0.05796456],
#        [ 0.01836491],
#        [-0.42710367],
#        [-0.40954262],
#        [-0.6843456 ],
#        [ 0.5208413 ],
#        [-0.6529978 ],
#        [ 0.25584924]], dtype=float32)>
#
# Bias
# <tf.Variable 'dense_29/bias:0' shape=(1,) dtype=float32, numpy=array([0.], dtype=float32)>

# %% [markdown]
# ## 2. Deep Neural Networks

# %% [markdown]
# Layers

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The Activation Function

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Stacking Dense Layers

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Building Sequential Models

# %%
from tensorflow import keras
from keras import layers
model = keras.Sequential([
    # the hidden ReLU layers
    layers.Dense(units=4, activation='relu', input_shape=[2]),
    layers.Dense(units=3, activation='relu'),
    # the linear output layer 
    layers.Dense(units=1),
])

# %% [markdown]
# ## 3. Stochastic Gradient Descent

# %% [markdown]
# Gradient Descent

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *   Batch gradient descent
# *   Mini-batch gradient descent
# * Stochastic gradient descent

# %% [markdown]
# The Loss Function

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The Optimizer - Stochastic Gradient Descent

# %% [markdown]
#  One step of training goes like this:
#
#
# 1.   Sample some training data and run it through the network to make predictions.
# 2.   Measure the loss between the predictions and the true values.
# 3. Finally, adjust the weights in a direction that makes the loss smaller.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Adding the Loss and Optimizer

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Example - Red Wine Quality

# %%
import pandas as pd
from IPython.display import display

red_wine = pd.read_csv('./file_csv/red-wine.csv')

# Create training and validation splits
df_train = red_wine.sample(frac=0.7, random_state=0)
df_valid = red_wine.drop(df_train.index)
display(df_train.head(4))

# Scale to [0, 1]
max_ = df_train.max(axis=0)
min_ = df_train.min(axis=0)
df_train = (df_train - min_) / (max_ - min_)
df_valid = (df_valid - min_) / (max_ - min_)

# Split features and target
X_train = df_train.drop('quality', axis=1)
X_valid = df_valid.drop('quality', axis=1)
y_train = df_train['quality']
y_valid = df_valid['quality']
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1109           10.8             0.470         0.43            2.10      0.171
# 1032            8.1             0.820         0.00            4.10      0.095
# 1002            9.1             0.290         0.33            2.05      0.063
# 487            10.2             0.645         0.36            1.80      0.053
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1109                 27.0                  66.0  0.99820  3.17       0.76
# 1032                  5.0                  14.0  0.99854  3.36       0.53
# 1002                 13.0                  27.0  0.99516  3.26       0.84
# 487                   5.0                  14.0  0.99820  3.17       0.42
#
#       alcohol  quality
# 1109     10.8        6
# 1032      9.6        5
# 1002     11.7        7
# 487      10.0        6

# %%
print(X_train.shape)
# Out:
# (1119, 11)

# %%
from tensorflow import keras
from keras import layers

model = keras.Sequential([
    layers.Dense(512, activation='relu', input_shape=[11]),
    layers.Dense(512, activation='relu'),
    layers.Dense(512, activation='relu'),
    layers.Dense(1),
])

# %%
model.compile(
    optimizer='adam',
    loss='mae',
)

# %%
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=256,
    epochs=10,
)
# Out:
# Epoch 1/10
# 5/5 [==============================] - 0s 32ms/step - loss: 0.2540 - val_loss: 0.1403
# Epoch 2/10
# 5/5 [==============================] - 0s 13ms/step - loss: 0.1360 - val_loss: 0.1243
# Epoch 3/10
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1233 - val_loss: 0.1234
# Epoch 4/10
# 5/5 [==============================] - 0s 14ms/step - loss: 0.1144 - val_loss: 0.1076
# Epoch 5/10
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1095 - val_loss: 0.1114
# Epoch 6/10
# 5/5 [==============================] - 0s 13ms/step - loss: 0.1077 - val_loss: 0.1032
# Epoch 7/10
# 5/5 [==============================] - 0s 14ms/step - loss: 0.1052 - val_loss: 0.1029
# Epoch 8/10
# 5/5 [==============================] - 0s 13ms/step - loss: 0.1026 - val_loss: 0.1002
# Epoch 9/10
# 5/5 [==============================] - 0s 12ms/step - loss: 0.1016 - val_loss: 0.0988
# Epoch 10/10
# 5/5 [==============================] - 0s 13ms/step - loss: 0.1025 - val_loss: 0.1036

# %%
import pandas as pd

# convert the training history to a dataframe
history_df = pd.DataFrame(history.history)
# use Pandas native plot method
history_df['loss'].plot();

# %% [markdown]
# ## 4. Overfitting and Underfitting

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *   Underfitting the training set is when the loss is not as low as it could be because the model hasn't learned enough signal.
# *    Overfitting the training set is when the loss is not as low as it could be because the model learned too much noise

# %% [markdown]
# Capacity

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Early Stopping

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Adding Early Stopping

# %%
from keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=20, # how many epochs to wait before stopping
    restore_best_weights=True,
)

# %% [markdown]
# Example - Train a Model with Early Stopping

# %%
import pandas as pd
from IPython.display import display

red_wine = pd.read_csv('./file_csv/red-wine.csv')

# Create training and validation splits
df_train = red_wine.sample(frac=0.7, random_state=0)
df_valid = red_wine.drop(df_train.index)
display(df_train.head(4))

# Scale to [0, 1]
max_ = df_train.max(axis=0)
min_ = df_train.min(axis=0)
df_train = (df_train - min_) / (max_ - min_)
df_valid = (df_valid - min_) / (max_ - min_)

# Split features and target
X_train = df_train.drop('quality', axis=1)
X_valid = df_valid.drop('quality', axis=1)
y_train = df_train['quality']
y_valid = df_valid['quality']
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1109           10.8             0.470         0.43            2.10      0.171
# 1032            8.1             0.820         0.00            4.10      0.095
# 1002            9.1             0.290         0.33            2.05      0.063
# 487            10.2             0.645         0.36            1.80      0.053
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1109                 27.0                  66.0  0.99820  3.17       0.76
# 1032                  5.0                  14.0  0.99854  3.36       0.53
# 1002                 13.0                  27.0  0.99516  3.26       0.84
# 487                   5.0                  14.0  0.99820  3.17       0.42
#
#       alcohol  quality
# 1109     10.8        6
# 1032      9.6        5
# 1002     11.7        7
# 487      10.0        6

# %%
from tensorflow import keras
from keras import layers, callbacks

early_stopping = callbacks.EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=20, # how many epochs to wait before stopping
    restore_best_weights=True,
)

model = keras.Sequential([
    layers.Dense(512, activation='relu', input_shape=[11]),
    layers.Dense(512, activation='relu'),
    layers.Dense(512, activation='relu'),
    layers.Dense(1),
])
model.compile(
    optimizer='adam',
    loss='mae',
)

# %%
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=256,
    epochs=500,
    callbacks=[early_stopping], # put your callbacks in a list
    verbose=0,  # turn off training log
)
history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot();
print("Minimum validation loss: {}".format(history_df['val_loss'].min()))
# Out:
# Minimum validation loss: 0.09225169569253922

# %% [markdown]
# ## 5. Dropout and Batch Normalization

# %% [markdown]
# Dropout

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Adding Dropout

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *Batch* Normalization

# %% [markdown]
# A batch normalization layer looks at each batch as it comes in, first normalizing the batch with its own mean and standard deviation, and then also putting the data on a new scale with two trainable rescaling parameters. Batchnorm, in effect, performs a kind of coordinated rescaling of its inputs.

# %% [markdown]
# **Adding** Batch Normalization

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Example - Using Dropout and Batch Normalization

# %%
from tensorflow import keras
from keras import layers

model = keras.Sequential([
    layers.Dense(1024, activation='relu', input_shape=[11]),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(1024, activation='relu'),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(1024, activation='relu'),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(1),
])

# %%
model.compile(
    optimizer='adam',
    loss='mae',
)

history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=256,
    epochs=100,
    verbose=0,
)


# Show the learning curves
history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot();

# %% [markdown]
# ##6. Binary Classification

# %% [markdown]
# Binary Cross-Entropy Loss

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Sigmoid Activation

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
from IPython.display import display

ion = pd.read_csv('./file_csv/ion.csv', index_col=0)
display(ion.head())

df = ion.copy()
df['Class'] = df['Class'].map({'good': 0, 'bad': 1})

df_train = df.sample(frac=0.7, random_state=0)
df_valid = df.drop(df_train.index)

max_ = df_train.max(axis=0)
min_ = df_train.min(axis=0)

df_train = (df_train - min_) / (max_ - min_)
df_valid = (df_valid - min_) / (max_ - min_)
df_train.dropna(axis=1, inplace=True) # drop the empty feature in column 2
df_valid.dropna(axis=1, inplace=True)

X_train = df_train.drop('Class', axis=1)
X_valid = df_valid.drop('Class', axis=1)
y_train = df_train['Class']
y_valid = df_valid['Class']
# Out:
#    V1  V2       V3       V4       V5       V6       V7       V8       V9  \
# 1   1   0  0.99539 -0.05889  0.85243  0.02306  0.83398 -0.37708  1.00000
# 2   1   0  1.00000 -0.18829  0.93035 -0.36156 -0.10868 -0.93597  1.00000
# 3   1   0  1.00000 -0.03365  1.00000  0.00485  1.00000 -0.12062  0.88965
# 4   1   0  1.00000 -0.45161  1.00000  1.00000  0.71216 -1.00000  0.00000
# 5   1   0  1.00000 -0.02401  0.94140  0.06531  0.92106 -0.23255  0.77152
#
#        V10  ...      V26      V27      V28      V29      V30      V31  \
# 1  0.03760  ... -0.51171  0.41078 -0.46168  0.21266 -0.34090  0.42267
# 2 -0.04549  ... -0.26569 -0.20468 -0.18401 -0.19040 -0.11593 -0.16626
# 3  0.01198  ... -0.40220  0.58984 -0.22145  0.43100 -0.17365  0.60436
# 4  0.00000  ...  0.90695  0.51613  1.00000  1.00000 -0.20099  0.25682
# 5 -0.16399  ... -0.65158  0.13290 -0.53206  0.02431 -0.62197 -0.05707
#
#        V32      V33      V34  Class
# 1 -0.54487  0.18641 -0.45300   good
# 2 -0.06288 -0.13738 -0.02447    bad
# 3 -0.24180  0.56045 -0.38238   good
# 4  1.00000 -0.32382  1.00000    bad
# 5 -0.59573 -0.04608 -0.65697   good
#
# [5 rows x 35 columns]

# %%
from tensorflow import keras
from keras import layers

model = keras.Sequential([
    layers.Dense(4, activation='relu', input_shape=[33]),
    layers.Dense(4, activation='relu'),    
    layers.Dense(1, activation='sigmoid'),
])

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['binary_accuracy'],
)

# %%
model.summary()
# Out:
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_45 (Dense)            (None, 4)                 136
#
#  dense_46 (Dense)            (None, 4)                 20
#
#  dense_47 (Dense)            (None, 1)                 5
#
# =================================================================
# Total params: 161
# Trainable params: 161
# Non-trainable params: 0
# _________________________________________________________________

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=10,
    min_delta=0.001,
    restore_best_weights=True,
)

history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=1000,
    callbacks=[early_stopping],
    verbose=0, # hide the output because we have so many epochs
)

# %%
history_df = pd.DataFrame(history.history)
# Start the plot at epoch 5
history_df.loc[5:, ['loss', 'val_loss']].plot()
history_df.loc[5:, ['binary_accuracy', 'val_binary_accuracy']].plot()

print(("Best Validation Loss: {:0.4f}" +\
      "\nBest Validation Accuracy: {:0.4f}")\
      .format(history_df['val_loss'].min(), 
              history_df['val_binary_accuracy'].max()))
# Out:
# Best Validation Loss: 0.5727
# Best Validation Accuracy: 0.7619

# %% [markdown]
# ## Use a neural network to predict cancellations in hotel reservations with the Hotel Cancellations dataset.

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer

hotel = pd.read_csv('./file_csv/hotel.csv')

hotel.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# 1                        0                     0       2  ...    No Deposit
# 2                        0                     1       1  ...    No Deposit
# 3                        0                     1       1  ...    No Deposit
# 4                        0                     2       2  ...    No Deposit
#
#    agent company days_in_waiting_list customer_type   adr  \
# 0    NaN     NaN                    0     Transient   0.0
# 1    NaN     NaN                    0     Transient   0.0
# 2    NaN     NaN                    0     Transient  75.0
# 3  304.0     NaN                    0     Transient  75.0
# 4  240.0     NaN                    0     Transient  98.0
#
#    required_car_parking_spaces  total_of_special_requests  reservation_status  \
# 0                            0                          0           Check-Out
# 1                            0                          0           Check-Out
# 2                            0                          0           Check-Out
# 3                            0                          0           Check-Out
# 4                            0                          1           Check-Out
#
#   reservation_status_date
# 0              2015-07-01
# 1              2015-07-01
# 2              2015-07-02
# 3              2015-07-02
# 4              2015-07-03
#
# [5 rows x 32 columns]

# %%
X = hotel.copy()
y = X.pop('is_canceled')

X['arrival_date_month'] = \
    X['arrival_date_month'].map(
        {'January':1, 'February': 2, 'March':3,
         'April':4, 'May':5, 'June':6, 'July':7,
         'August':8, 'September':9, 'October':10,
         'November':11, 'December':12}
    )

features_num = [
    "lead_time", "arrival_date_week_number",
    "arrival_date_day_of_month", "stays_in_weekend_nights",
    "stays_in_week_nights", "adults", "children", "babies",
    "is_repeated_guest", "previous_cancellations",
    "previous_bookings_not_canceled", "required_car_parking_spaces",
    "total_of_special_requests", "adr",
]
features_cat = [
    "hotel", "arrival_date_month", "meal",
    "market_segment", "distribution_channel",
    "reserved_room_type", "deposit_type", "customer_type",
]

transformer_num = make_pipeline(
    SimpleImputer(strategy="constant"), # there are a few missing values
    StandardScaler(),
)
transformer_cat = make_pipeline(
    SimpleImputer(strategy="constant", fill_value="NA"),
    OneHotEncoder(handle_unknown='ignore'),
)

preprocessor = make_column_transformer(
    (transformer_num, features_num),
    (transformer_cat, features_cat),
)

# stratify - make sure classes are evenlly represented across splits
X_train, X_valid, y_train, y_valid = \
    train_test_split(X, y, stratify=y, train_size=0.75)

X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)

input_shape = [X_train.shape[1]]

# %% [markdown]
# 1. Define Model

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from tensorflow import keras
from keras import layers

model =keras.Sequential([
    layers.BatchNormalization(input_shape = input_shape),
    layers.Dense(256, activation = "relu"),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(256, activation = "relu"),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(1, activation ="sigmoid")
    
])

# %% [markdown]
# 2. Add Optimizer, Loss, and Metric

# %%
model.compile(
optimizer = "Adam",
loss = "binary_crossentropy",
metrics = ["binary_accuracy"],
)

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=5,
    min_delta=0.001,
    restore_best_weights=True,
)

# %%
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=200,
    callbacks=[early_stopping],
)
# Out:
# Epoch 1/200
# 175/175 [==============================] - 2s 8ms/step - loss: 0.4800 - binary_accuracy: 0.7720 - val_loss: 0.4335 - val_binary_accuracy: 0.8003
# Epoch 2/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.4234 - binary_accuracy: 0.8010 - val_loss: 0.4011 - val_binary_accuracy: 0.8140
# Epoch 3/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.4096 - binary_accuracy: 0.8086 - val_loss: 0.3952 - val_binary_accuracy: 0.8171
# Epoch 4/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.4029 - binary_accuracy: 0.8121 - val_loss: 0.3916 - val_binary_accuracy: 0.8191
# Epoch 5/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3978 - binary_accuracy: 0.8143 - val_loss: 0.3865 - val_binary_accuracy: 0.8212
# Epoch 6/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3939 - binary_accuracy: 0.8164 - val_loss: 0.3836 - val_binary_accuracy: 0.8227
# Epoch 7/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3890 - binary_accuracy: 0.8182 - val_loss: 0.3824 - val_binary_accuracy: 0.8279
# Epoch 8/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3861 - binary_accuracy: 0.8202 - val_loss: 0.3825 - val_binary_accuracy: 0.8256
# Epoch 9/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3819 - binary_accuracy: 0.8232 - val_loss: 0.3758 - val_binary_accuracy: 0.8299
# Epoch 10/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3796 - binary_accuracy: 0.8247 - val_loss: 0.3724 - val_binary_accuracy: 0.8305
# Epoch 11/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3763 - binary_accuracy: 0.8253 - val_loss: 0.3734 - val_binary_accuracy: 0.8294
# Epoch 12/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3743 - binary_accuracy: 0.8263 - val_loss: 0.3721 - val_binary_accuracy: 0.8316
# Epoch 13/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3734 - binary_accuracy: 0.8265 - val_loss: 0.3720 - val_binary_accuracy: 0.8326
# Epoch 14/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3704 - binary_accuracy: 0.8279 - val_loss: 0.3677 - val_binary_accuracy: 0.8333
# Epoch 15/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3683 - binary_accuracy: 0.8282 - val_loss: 0.3669 - val_binary_accuracy: 0.8324
# Epoch 16/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3660 - binary_accuracy: 0.8310 - val_loss: 0.3672 - val_binary_accuracy: 0.8351
# Epoch 17/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3653 - binary_accuracy: 0.8311 - val_loss: 0.3639 - val_binary_accuracy: 0.8359
# Epoch 18/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3630 - binary_accuracy: 0.8320 - val_loss: 0.3638 - val_binary_accuracy: 0.8357
# Epoch 19/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3617 - binary_accuracy: 0.8313 - val_loss: 0.3624 - val_binary_accuracy: 0.8352
# Epoch 20/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3606 - binary_accuracy: 0.8327 - val_loss: 0.3654 - val_binary_accuracy: 0.8354
# Epoch 21/200
# 175/175 [==============================] - 2s 9ms/step - loss: 0.3578 - binary_accuracy: 0.8347 - val_loss: 0.3635 - val_binary_accuracy: 0.8352
# Epoch 22/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3564 - binary_accuracy: 0.8337 - val_loss: 0.3646 - val_binary_accuracy: 0.8361
# Epoch 23/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3563 - binary_accuracy: 0.8360 - val_loss: 0.3587 - val_binary_accuracy: 0.8379
# Epoch 24/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3553 - binary_accuracy: 0.8361 - val_loss: 0.3581 - val_binary_accuracy: 0.8376
# Epoch 25/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3513 - binary_accuracy: 0.8376 - val_loss: 0.3587 - val_binary_accuracy: 0.8377
# Epoch 26/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3521 - binary_accuracy: 0.8362 - val_loss: 0.3570 - val_binary_accuracy: 0.8406
# Epoch 27/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3520 - binary_accuracy: 0.8373 - val_loss: 0.3576 - val_binary_accuracy: 0.8390
# Epoch 28/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3499 - binary_accuracy: 0.8371 - val_loss: 0.3595 - val_binary_accuracy: 0.8372
# Epoch 29/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3483 - binary_accuracy: 0.8390 - val_loss: 0.3598 - val_binary_accuracy: 0.8374
# Epoch 30/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3485 - binary_accuracy: 0.8382 - val_loss: 0.3583 - val_binary_accuracy: 0.8380
# Epoch 31/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3474 - binary_accuracy: 0.8399 - val_loss: 0.3607 - val_binary_accuracy: 0.8379

# %%
history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot(title="Cross-entropy")
history_df.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot(title="Accuracy")
# Out:
# <AxesSubplot: title={'center': 'Accuracy'}>

# %%
Y_new = model.predict(X_valid)
# Out:
# 933/933 [==============================] - 1s 534us/step
