# %% [markdown]
# ### <h4>Đọc dữ liệu</h4>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./AB_NYC_2019.csv")
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# ### <h4>Câu 1: Vẽ biểu đồ cột cho neighborhood group</h4>

# %%
plt.bar(df['neighbourhood_group'], df['price'], color="red")

plt.xlabel("neighbourhood_group")
plt.ylabel("price")
plt.show()

# %% [markdown]
# ###   <h4>Câu 2: Tạo histogram cho neighbourhood</h4>

# %%
plt.hist(df['neighbourhood'])

plt.title("neightbourhood_histogram")

plt.show()
# df.count()

# %%
# kiểm tra
df.neighbourhood_group.value_counts(dropna=True)
# Out:
# Manhattan        21661
# Brooklyn         20104
# Queens            5666
# Bronx             1091
# Staten Island      373
# Name: neighbourhood_group, dtype: int64

# %% [markdown]
# ### <h4>Câu 3: Biểu diễn mối liên hệ giữa neighbourgroup và Availability của các phòng </h4>

# %%
df.isna().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
import seaborn as sns

# %%
plt.bar( df['neighbourhood_group'],df['availability_365'], color='red')

plt.xlabel("neighbourhood_group")
plt.ylabel("availability_365")

plt.show()

# %% [markdown]
# ### <h4>Câu 4: Vẽ bản đồ (scatter plot) của neighborhood dựa theo tọa độ lat lon</h4>

# %%
plt.scatter(df['neighbourhood'], df['price'])

plt.show()

# %% [markdown]
# ### <h4>Câu 5: Sử dụng heatmap để biểu diễn mối quan hệ (correlation) giữa tất cả các thuộc tính trong dữ liệu</h4>

# %%
import seaborn as sns
import numpy as np
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df1 = df.drop('name', axis=1)
df2 = df1.copy()
df2 = df2.drop('host_name', axis=1)
df2 = df2.drop('neighbourhood_group', axis=1)
df2 = df2.drop('neighbourhood', axis=1)
df2 = df2.drop('room_type', axis=1)
df2 = df2.drop('last_review', axis=1)
df2 = df2.drop('reviews_per_month', axis=1)
df2 = df2.drop('id', axis=1)
df2 = df2.drop('host_id', axis=1)
df2 = df2.drop('latitude', axis=1)
df2 = df2.drop('longitude', axis=1)
display(df2)
# nump = np.array(df2)

sns.heatmap(data=df2, vmin=0, vmax=500, cmap='tab20')
plt.show()
# Out:
#        price  minimum_nights  number_of_reviews  \
# 0        149               1                  9
# 1        225               1                 45
# 2        150               3                  0
# 3         89               1                270
# 4         80              10                  9
# ...      ...             ...                ...
# 48890     70               2                  0
# 48891     40               4                  0
# 48892    115              10                  0
# 48893     55               1                  0
# 48894     90               7                  0
#
#        calculated_host_listings_count  availability_365
# 0                                   6               365
# 1                                   2               355
# 2                                   1               365
# 3                                   1               194
# 4                                   1                 0
# ...
