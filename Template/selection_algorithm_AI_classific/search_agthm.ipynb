# %%
from pandas import read_csv
from pycaret.classification import setup
from pycaret.classification import compare_models

# %%
from pandas import read_csv
from pycaret.classification import setup
from pycaret.classification import compare_models
# define the location of the dataset
# load the dataset
df = read_csv("./file_csv/train_PTIT.csv")
# set column names as the column number
n_cols = df.shape[1]
df.columns = [str(i) for i in range(n_cols)]
# setup the dataset
grid = setup(data=df, target=df.columns[-1], html=False, silent=True, verbose=False)
# evaluate models and compare models
best = compare_models()
# report the best model
print(best)
# Out:
#                   Model  Accuracy     AUC  Recall   Prec.     F1   Kappa  \
# lr  Logistic Regression    0.7033  0.9296  0.6594  0.7086  0.698  0.6353
#
#        MCC  TT (Sec)
# lr  0.6377     4.711
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                       Model  Accuracy     AUC  Recall   Prec.      F1   Kappa  \
# lr      Logistic Regression    0.7033  0.9296  0.6594  0.7086  0.6980  0.6353
# knn  K Neighbors Classifier    0.4423  0.7318  0.3680  0.4743  0.4106  0.3192
#
#         MCC  TT (Sec)
# lr   0.6377     4.711
# knn  0.3298     0.571
#                       Model  Accuracy     AUC  Recall   Prec.      F1   Kappa  \
# lr      Logistic Regression    0.7033  0.9296  0.6594  0.7086  0.6980  0.6353
# nb              Naive Bayes    0.4657  0.6851  0.4286  0.4677  0.4631  0.3484
# knn  K Neighbors Classifier    0.4423  0.7318  0.3680  0.4743  0.4106  0.3192
#
#         MCC  TT (Sec)
# lr   0.6377     4.711
# nb   0.3494     0.068
# knn  0.3298     0.571
#                         Model  Accuracy     AUC  Recall   Prec.      F1  \
# lr        Logistic Regression    0.7033  0.9296  0.6594  0.7086  0.6980
# dt   Decision Tree Classifier    0.5514  0.7294  0.5108  0.5602  0.5497
# nb                Naive Bayes    0.4657  0.6851  0.4286  0.4677  0.4631
# knn    K Neighbors Classifier    0.4423  0.7318  0.3680  0.4743  0.4106
#
#       Kappa     MCC  TT (Sec)
# lr   0.6353  0.6377     4.711
# dt   0.4554  0.4572     0.104
# nb   0.3484  0.3494     0.068
# knn  0.3192  0.3298     0.571
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
#                         Model  Accuracy     AUC  Recall   Prec.      F1  \
# lr        Logistic Regression    0.7033  0.9296  0.6594  0.7086  0.6980
# dt   Decision Tree Classifier    0.5514  0.7294  0.5108  0.5602  0.5497
# svm       SVM - Linear Kernel    0.5414  0.0000  0.4996  0.7005  0.5137
# nb                Naive Bayes    0.4657  0.6851  0.4286  0.4677  0.4631
# knn    K Neighbors Classifier    0.4423  0.7318  0.3680  0.4743  0.4106
#
#       Kappa     MCC  TT (Sec)
# lr   0.6353  0.6377     4.711
# dt   0.4554  0.4572     0.104
# svm  0.4443  0.4695     0.420
# nb   0.3484  0.3494     0.068
# knn  0.3192  0.3298     0.571
#                           Model  Accuracy     AUC  Recall   Prec.      F1  \
# lr          Logistic Regression    0.7033  0.9296  0.6594  0.7086  0.6980
# ridge          Ridge Classifier    0.6305  0.0000  0.5887  0.6351  0.6268
# dt     Decision Tree Classifier    0.5514  0.7294  0.5108  0.5602  0.5497
# svm         SVM - Linear Kernel    0.5414  0.0000  0.4996  0.7005  0.5137
# nb                  Naive Bayes    0.4657  0.6851  0.4286  0.4677  0.4631
# knn      K Neighbors Classifier    0.4423  0.7318  0.3680  0.4743  0.4106
#
#         Kappa     MCC  TT (Sec)
# lr     0.6353  0.6377     4.711
# ridge  0.5475  0.5492     0.102
# dt     0.4554  0.4572     0.104
# svm    0.4443  0.4695     0.420
# nb     0.3484  0.3494     0.068
# knn    0.3192  0.3298     0.571
#                           Model  Accuracy     AUC  Recall   Prec.      F1  \
# lr          Logistic Regression    0.7033  0.9296  0.6594  0.7086  0.6980
# rf     Random Forest Classifier    0.6903  0.9212  0.6273  0.6950  0.6810
# ridge          Ridge Classifier    0.6305  0.0000  0.5887  0.6351  0.6268
# dt     Decision Tree Classifier    0.5514  0.7294  0.5108  0.5602  0.5497
# svm         SVM - Linear Kernel    0.5414  0.0000  0.4996  0.7005  0.5137
# nb                  Naive Bayes    0.4657  0.6851  0.4286  0.4677  0.4631
# knn      K Neighbors Classifier    0.4423  0.7318  0.3680  0.4743  0.4106
#
#         Kappa     MCC  TT (Sec)
# lr     0.6353  0.6377     4.711
# rf     0.6185  0.6209     0.354
# ridge  0.5475  0.5492     0.102
# dt     0.4554  0.4572     0.104
# svm    0.4443  0.4695     0.420
# nb     0.3484  0.3494     0.068
# knn    0.3192  0.3298     0.571
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                                  Model  Accuracy     AUC  Recall   Prec.  \
# lr                 Logistic Regression    0.7033  0.9296  0.6594  0.7086
# rf            Random Forest Classifier    0.6903  0.9212  0.6273  0.6950
# ridge                 Ridge Classifier    0.6305  0.0000  0.5887  0.6351
# dt            Decision Tree Classifier    0.5514  0.7294  0.5108  0.5602
# svm                SVM - Linear Kernel    0.5414  0.0000  0.4996  0.7005
# nb                         Naive Bayes    0.4657  0.6851  0.4286  0.4677
# knn             K Neighbors Classifier    0.4423  0.7318  0.3680  0.4743
# qda    Quadratic Discriminant Analysis    0.1314  0.5075  0.1637  0.0879
#
#            F1   Kappa     MCC  TT (Sec)
# lr     0.6980  0.6353  0.6377     4.711
# rf     0.6810  0.6185  0.6209     0.354
# ridge  0.6268  0.5475  0.5492     0.102
# dt     0.5497  0.4554  0.4572     0.104
# svm    0.5137  0.4443  0.4695     0.420
# nb     0.4631  0.3484  0.3494     0.068
# knn    0.4106  0.3192  0.3298     0.571
# qda    0.0984  0.0152  0.0167     0.243
#                                  Model  Accuracy     AUC  Recall   Prec.  \
# lr                 Logistic Regression    0.7033  0.9296  0.6594  0.7086
# rf            Random Forest Classifier    0.6903  0.9212  0.6273  0.6950
# ridge                 Ridge Classifier    0.6305  0.0000  0.5887  0.6351
# dt            Decision Tree Classifier    0.5514  0.7294  0.5108  0.5602
# svm                SVM - Linear Kernel    0.5414  0.0000  0.4996  0.7005
# ada               Ada Boost Classifier    0.4839  0.7212  0.4429  0.5420
# nb                         Naive Bayes    0.4657  0.6851  0.4286  0.4677
# knn             K Neighbors Classifier    0.4423  0.7318  0.3680  0.4743
# qda    Quadratic Discriminant Analysis    0.1314  0.5075  0.1637  0.0879
#
#            F1   Kappa     MCC  TT (Sec)
# lr     0.6980  0.6353  0.6377     4.711
# rf     0.6810  0.6185  0.6209     0.354
# ridge  0.6268  0.5475  0.5492     0.102
# dt     0.5497  0.4554  0.4572     0.104
# svm    0.5137  0.4443  0.4695     0.420
# ada    0.4801  0.3615  0.3692     0.189
# nb     0.4631  0.3484  0.3494     0.068
# knn    0.4106  0.3192  0.3298     0.571
# qda    0.0984  0.0152  0.0167     0.243
#                                  Model  Accuracy     AUC  Recall   Prec.  \
# lr                 Logistic Regression    0.7033  0.9296  0.6594  0.7086
# rf            Random Forest Classifier    0.6903  0.9212  0.6273  0.6950
# gbc       Gradient Boosting Classifier    0.6868  0.9140  0.6331  0.6984
# ridge                 Ridge Classifier    0.6305  0.0000  0.5887  0.6351
# dt            Decision Tree Classifier    0.5514  0.7294  0.5108  0.5602
# svm                SVM - Linear Kernel    0.5414  0.0000  0.4996  0.7005
# ada               Ada Boost Classifier    0.4839  0.7212  0.4429  0.5420
# nb                         Naive Bayes    0.4657  0.6851  0.4286  0.4677
# knn             K Neighbors Classifier    0.4423  0.7318  0.3680  0.4743
# qda    Quadratic Discriminant Analysis    0.1314  0.5075  0.1637  0.0879
#
#            F1   Kappa     MCC  TT (Sec)
# lr     0.6980  0.6353  0.6377     4.711
# rf     0.6810  0.6185  0.6209     0.354
# gbc    0.6805  0.6110  0.6160     3.314
# ridge  0.6268  0.5475  0.5492     0.102
# dt     0.5497  0.4554  0.4572     0.104
# svm    0.5137  0.4443  0.4695     0.420
# ada    0.4801  0.3615  0.3692     0.189
# nb     0.4631  0.3484  0.3494     0.068
# knn    0.4106  0.3192  0.3298     0.571
# qda    0.0984  0.0152  0.0167     0.243
#                                  Model  Accuracy     AUC  Recall   Prec.  \
# lr                 Logistic Regression    0.7033  0.9296  0.6594  0.7086
# rf            Random Forest Classifier    0.6903  0.9212  0.6273  0.6950
# gbc       Gradient Boosting Classifier    0.6868  0.9140  0.6331  0.6984
# ridge                 Ridge Classifier    0.6305  0.0000  0.5887  0.6351
# dt            Decision Tree Classifier    0.5514  0.7294  0.5108  0.5602
# svm                SVM - Linear Kernel    0.5414  0.0000  0.4996  0.7005
# ada               Ada Boost Classifier    0.4839  0.7212  0.4429  0.5420
# nb                         Naive Bayes    0.4657  0.6851  0.4286  0.4677
# knn             K Neighbors Classifier    0.4423  0.7318  0.3680  0.4743
# lda       Linear Discriminant Analysis    0.4329  0.7465  0.4277  0.4575
# qda    Quadratic Discriminant Analysis    0.1314  0.5075  0.1637  0.0879
#
#            F1   Kappa     MCC  TT (Sec)
# lr     0.6980  0.6353  0.6377     4.711
# rf     0.6810  0.6185  0.6209     0.354
# gbc    0.6805  0.6110  0.6160     3.314
# ridge  0.6268  0.5475  0.5492     0.102
# dt     0.5497  0.4554  0.4572     0.104
# svm    0.5137  0.4443  0.4695     0.420
# ada    0.4801  0.3615  0.3692     0.189
# nb     0.4631  0.3484  0.3494     0.068
# knn    0.4106  0.3192  0.3298     0.571
# lda    0.4361  0.3232  0.3260     3.048
# qda    0.0984  0.0152  0.0167     0.243
#                                  Model  Accuracy     AUC  Recall   Prec.  \
# lr                 Logistic Regression    0.7033  0.9296  0.6594  0.7086
# et              Extra Trees Classifier    0.6951  0.9210  0.6398  0.6981
# rf            Random Forest Classifier    0.6903  0.9212  0.6273  0.6950
# gbc       Gradient Boosting Classifier    0.6868  0.9140  0.6331  0.6984
# ridge                 Ridge Classifier    0.6305  0.0000  0.5887  0.6351
# dt            Decision Tree Classifier    0.5514  0.7294  0.5108  0.5602
# svm                SVM - Linear Kernel    0.5414  0.0000  0.4996  0.7005
# ada               Ada Boost Classifier    0.4839  0.7212  0.4429  0.5420
# nb                         Naive Bayes    0.4657  0.6851  0.4286  0.4677
# knn             K Neighbors Classifier    0.4423  0.7318  0.3680  0.4743
# lda       Linear Discriminant Analysis    0.4329  0.7465  0.4277  0.4575
# qda    Quadratic Discriminant Analysis    0.1314  0.5075  0.1637  0.0879
#
#            F1   Kappa     MCC  TT (Sec)
# lr     0.6980  0.6353  0.6377     4.711
# et     0.6886  0.6259  0.6277     0.520
# rf     0.6810  0.6185  0.6209     0.354
# gbc    0.6805  0.6110  0.6160     3.314
# ridge  0.6268  0.5475  0.5492     0.102
# dt     0.5497  0.4554  0.4572     0.104
# svm    0.5137  0.4443  0.4695     0.420
# ada    0.4801  0.3615  0.3692     0.189
# nb     0.4631  0.3484  0.3494     0.068
# knn    0.4106  0.3192  0.3298     0.571
# lda    0.4361  0.3232  0.3260     3.048
# qda    0.0984  0.0152  0.0167     0.243
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lr                    Logistic Regression    0.7033  0.9296  0.6594  0.7086
# et                 Extra Trees Classifier    0.6951  0.9210  0.6398  0.6981
# rf               Random Forest Classifier    0.6903  0.9212  0.6273  0.6950
# gbc          Gradient Boosting Classifier    0.6868  0.9140  0.6331  0.6984
# lightgbm  Light Gradient Boosting Machine    0.6850  0.9174  0.6294  0.6878
# ridge                    Ridge Classifier    0.6305  0.0000  0.5887  0.6351
# dt               Decision Tree Classifier    0.5514  0.7294  0.5108  0.5602
# svm                   SVM - Linear Kernel    0.5414  0.0000  0.4996  0.7005
# ada                  Ada Boost Classifier    0.4839  0.7212  0.4429  0.5420
# nb                            Naive Bayes    0.4657  0.6851  0.4286  0.4677
# knn                K Neighbors Classifier    0.4423  0.7318  0.3680  0.4743
# lda          Linear Discriminant Analysis    0.4329  0.7465  0.4277  0.4575
# qda       Quadratic Discriminant Analysis    0.1314  0.5075  0.1637  0.0879
#
#               F1   Kappa     MCC  TT (Sec)
# lr        0.6980  0.6353  0.6377     4.711
# et        0.6886  0.6259  0.6277     0.520
# rf        0.6810  0.6185  0.6209     0.354
# gbc       0.6805  0.6110  0.6160     3.314
# lightgbm  0.6782  0.6120  0.6146     0.186
# ridge     0.6268  0.5475  0.5492     0.102
# dt        0.5497  0.4554  0.4572     0.104
# svm       0.5137  0.4443  0.4695     0.420
# ada       0.4801  0.3615  0.3692     0.189
# nb        0.4631  0.3484  0.3494     0.068
# knn       0.4106  0.3192  0.3298     0.571
# lda       0.4361  0.3232  0.3260     3.048
# qda       0.0984  0.0152  0.0167     0.243
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/vutuyen/Documents/W- Suzurain (W5)/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lr                    Logistic Regression    0.7033  0.9296  0.6594  0.7086
# et                 Extra Trees Classifier    0.6951  0.9210  0.6398  0.6981
# rf               Random Forest Classifier    0.6903  0.9212  0.6273  0.6950
# gbc          Gradient Boosting Classifier    0.6868  0.9140  0.6331  0.6984
# lightgbm  Light Gradient Boosting Machine    0.6850  0.9174  0.6294  0.6878
# ridge                    Ridge Classifier    0.6305  0.0000  0.5887  0.6351
# dt               Decision Tree Classifier    0.5514  0.7294  0.5108  0.5602
# svm                   SVM - Linear Kernel    0.5414  0.0000  0.4996  0.7005
# ada                  Ada Boost Classifier    0.4839  0.7212  0.4429  0.5420
# nb                            Naive Bayes    0.4657  0.6851  0.4286  0.4677
# knn                K Neighbors Classifier    0.4423  0.7318  0.3680  0.4743
# lda          Linear Discriminant Analysis    0.4329  0.7465  0.4277  0.4575
# dummy                    Dummy Classifier    0.2974  0.5000  0.1429  0.0884
# qda       Quadratic Discriminant Analysis    0.1314  0.5075  0.1637  0.0879
#
#               F1   Kappa     MCC  TT (Sec)
# lr        0.6980  0.6353  0.6377     4.711
# et        0.6886  0.6259  0.6277     0.520
# rf        0.6810  0.6185  0.6209     0.354
# gbc       0.6805  0.6110  0.6160     3.314
# lightgbm  0.6782  0.6120  0.6146     0.186
# ridge     0.6268  0.5475  0.5492     0.102
# dt        0.5497  0.4554  0.4572     0.104
# svm       0.5137  0.4443  0.4695     0.420
# ada       0.4801  0.3615  0.3692     0.189
# nb        0.4631  0.3484  0.3494     0.068
# knn       0.4106  0.3192  0.3298     0.571
# lda       0.4361  0.3232  0.3260     3.048
# dummy     0.1363  0.0000  0.0000     0.018
# qda       0.0984  0.0152  0.0167     0.243
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lr                    Logistic Regression    0.7033  0.9296  0.6594  0.7086
# et                 Extra Trees Classifier    0.6951  0.9210  0.6398  0.6981
# rf               Random Forest Classifier    0.6903  0.9212  0.6273  0.6950
# gbc          Gradient Boosting Classifier    0.6868  0.9140  0.6331  0.6984
# lightgbm  Light Gradient Boosting Machine    0.6850  0.9174  0.6294  0.6878
# ridge                    Ridge Classifier    0.6305  0.0000  0.5887  0.6351
# dt               Decision Tree Classifier    0.5514  0.7294  0.5108  0.5602
# svm                   SVM - Linear Kernel    0.5414  0.0000  0.4996  0.7005
# ada                  Ada Boost Classifier    0.4839  0.7212  0.4429  0.5420
# nb                            Naive Bayes    0.4657  0.6851  0.4286  0.4677
# knn                K Neighbors Classifier    0.4423  0.7318  0.3680  0.4743
# lda          Linear Discriminant Analysis    0.4329  0.7465  0.4277  0.4575
# dummy                    Dummy Classifier    0.2974  0.5000  0.1429  0.0884
# qda       Quadratic Discriminant Analysis    0.1314  0.5075  0.1637  0.0879
#
#               F1   Kappa     MCC  TT (Sec)
# lr        0.6980  0.6353  0.6377     4.711
# et        0.6886  0.6259  0.6277     0.520
# rf        0.6810  0.6185  0.6209     0.354
# gbc       0.6805  0.6110  0.6160     3.314
# lightgbm  0.6782  0.6120  0.6146     0.186
# ridge     0.6268  0.5475  0.5492     0.102
# dt        0.5497  0.4554  0.4572     0.104
# svm       0.5137  0.4443  0.4695     0.420
# ada       0.4801  0.3615  0.3692     0.189
# nb        0.4631  0.3484  0.3494     0.068
# knn       0.4106  0.3192  0.3298     0.571
# lda       0.4361  0.3232  0.3260     3.048
# dummy     0.1363  0.0000  0.0000     0.018
# qda       0.0984  0.0152  0.0167     0.243
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=643, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)
